# %% [markdown]
# <a href="https://colab.research.google.com/github/frozenpwr/GC/blob/main/%D0%9B%D0%B5%D0%BA%D1%86%D0%B8%D1%8F_28_08_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df1=pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df2=pd.DataFrame({'x':[3,1,1], 'y':[0,2,None]})

display((df1==2)|(df2<3))
display(df)
display(df2.isnull())

df2.loc[df2.isnull()['y']==False]

print(df2['x'].sum())
print(df2['x'].mean())
print(df2['x'].median())
print(df2['x'].std())
print(df2['x'].unique())
print(df1.corr())
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1
#        x      y
# 0  False  False
# 1  False  False
# 2  False   True
# 5
# 1.6666666666666667
# 1.0
# 1.1547005383792517
# [3 1]
#           x         y
# x  1.000000  0.654654
# y  0.654654  1.000000

# %%
#     индекс  ось     применяется к исх. ДФ
df.drop(1,axis=0,inplace=True)
display(df)
# Out:
#    x  y
# 0  1  2
# 2  2  1

# %%
del df['x'] # df.drop('x', axis=1)
display(df)
# Out:
#    y
# 0  2
# 1  4
# 2  1

# %%
df.reset_index(drop=True)
# Out:
#    x  y
# 0  1  2
# 1  2  1
